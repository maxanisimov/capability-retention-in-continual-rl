# %%
import pandas

# %%
safe_optimal_policy_df = pandas.read_csv(
    '/Users/ma5923/Documents/_projects/CertifiedContinualLearning/rl_project/experiments/poisoned_apple/tables/poisoned_apple_demo_results_simple_5x5_Safe Optimal Policy Data.csv'
)

safe_training_data_df = pandas.read_csv(
    '/Users/ma5923/Documents/_projects/CertifiedContinualLearning/rl_project/experiments/poisoned_apple/tables/poisoned_apple_demo_results_simple_5x5_Safe Training Data.csv'
)

# %%
safe_optimal_policy_df
# Out:
#                 Unnamed: 0  Standard Actor / Env 1  Standard Actor / Env 2  \
# 0               avg_reward                    1.96                   -0.04
# 1  avg_performance_success                    1.00                    1.00
# 2       avg_safety_success                    1.00                    0.50
# 3      avg_overall_success                    1.00                    0.00
#
#    Rashomon Actor / Env 1  Rashomon Actor / Env 2
# 0                    1.96                    0.96
# 1                    1.00                    1.00
# 2                    1.00                    1.00
# 3                    1.00                    1.00
