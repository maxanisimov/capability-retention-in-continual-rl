# %%
import pandas
import os

# %%
tables_folder = '/vol/bitbucket/ma5923/_projects/CertifiedContinualLearning/rl_project/experiments/simple_navigation/poisoned_apple/tables'
table_files = os.listdir(tables_folder)
dfs_dct = {
    file_name.replace('results_simple_', '').replace('.csv', '').replace('_Sufficient_Safety_Data', ''): pandas.read_csv(os.path.join(tables_folder, file_name))
    for file_name in table_files
}
poisoned_apple_table_df = pandas.concat(dfs_dct)

# %%
poisoned_apple_table_df.to_latex(index=False, booktabs=True, caption="Results for Poisoned Apple Environment", label="tab:poisoned_apple_results")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 poisoned_apple_table_df.to_latex(index=False, booktabs=True, caption="Results for Poisoned Apple Environment", label="tab:poisoned_apple_results")
#
# File /vol/bitbucket/ma5923/_projects/CertifiedContinualLearning/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_latex() got an unexpected keyword argument 'booktabs'

# %%
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# Unnamed: 0 & NoAdapt / Task 1 & NoAdapt / Task 2 & SafeAdapt / Task 1 & SafeAdapt / Task 2 \\
# \midrule
# avg_reward & 1.960000 & -0.040000 & 0.910000 & 0.960000 \\
# avg_performance_success & 1.000000 & 1.000000 & 0.500000 & 1.000000 \\
# avg_safety_success & 1.000000 & 0.500000 & 1.000000 & 1.000000 \\
# avg_overall_success & 1.000000 & 0.000000 & 0.000000 & 1.000000 \\
# \bottomrule
# \end{tabular}

# %%
print(df.to_latex(index=False, booktabs=True, caption="My table", label="tab:results"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(df.to_latex(index=False, booktabs=True, caption="My table", label="tab:results"))
#
# File /vol/bitbucket/ma5923/_projects/CertifiedContinualLearning/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_latex() got an unexpected keyword argument 'booktabs'
